# %% [markdown]
# # Question 1

# %% [markdown]
# Prepare a case study for the given Dataset to implement the following:
#
# Import different required library
#
# Check the version of the Library
#
# Go for different observation like info, description
#
# Check  null values.
#
# Check duplicate values
#
# Filter for different condition come up with insights from the dataset, basic plot, distribution plots.
#
# Use s Histogram to plot different columns,

# %% [markdown]
# # Credit Card Case study

# %%
import os 
os.chdir("C:\Datasets")

# %%
import pandas as pd
card_data = pd.read_csv("creditcard.csv")

# %%
#To show the first five entries
card_data.head()
# Out:
#    Target        V1        V2        V3        V4        V5        V6  \
# 0     0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1     0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2     1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3     1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4     2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
card_data.shape # the  dataset has 284807 rows and 31 columns
# Out:
# (284807, 31)

# %%
card_data.dtypes.value_counts()
# Out:
# float64    30
# object      1
# dtype: int64

# %%
card_data = pd.read_csv("creditcard.csv")

# %%
# to check information of the dataset.
card_data.info
# Out:
# <bound method DataFrame.info of           Target         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
card_data.isna()
# Out:
#         Target     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0        False  False  False  False  False  False  False  False  False  False
# 1        False  False  False  False  False  False  False  False  False  False
# 2        False  False  False  False  False  False  False  False  False  False
# 3        False  False  False  False  False  False  False  False  False  False
# 4        False  False  False  False  False  False  False  False  False  False
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 284802   False  False  False  False  False  False  False  False  False  False
# 284803   False  False  False  False  False  False  False  False  False  False
# 284804   False  False  False  False  False  False  False  False  False  False
# 284805   False  False  False  False  False  False  False  False  False  False
# 284806   False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
card_data.min()
# Out:
# Target          0
# V1       -56.4075
# V2       -72.7157
# V3       -48.3256
# V4       -5.68317
# V5       -113.743
# V6       -26.1605
# V7       -43.5572
# V8       -73.2167
# V9       -13.4341
# V10      -24.5883
# V11      -4.79747
# V12      -18.6837
# V13      -5.79188
# V14      -19.2143
# V15      -4.49894
# V16      -14.1299
# V17      -25.1628
# V18      -9.49875
# V19      -7.21353
# V20      -54.4977
# V21      -34.8304
# V22      -10.9331
# V23      -44.8077
# V24      -2.83663
# V25      -10.2954
# V26      -2.60455
# V27      -22.5657
# V28      -15.4301
# Amount          0
# Class         '0'
# dtype: object

# %%
card_data.max()
# Out:
# Target     172792
# V1        2.45493
# V2        22.0577
# V3        9.38256
# V4        16.8753
# V5        34.8017
# V6        73.3016
# V7        120.589
# V8        20.0072
# V9         15.595
# V10       23.7451
# V11       12.0189
# V12       7.84839
# V13       7.12688
# V14       10.5268
# V15       8.87774
# V16       17.3151
# V17       9.25353
# V18       5.04107
# V19       5.59197
# V20       39.4209
# V21       27.2028
# V22       10.5031
# V23       22.5284
# V24       4.58455
# V25       7.51959
# V26       3.51735
# V27       31.6122
# V28       33.8478
# Amount    25691.2
# Class         '1'
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
card_data.describe()
# Out:
#               Target            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.758743e-12 -8.252298e-13 -9.636929e-13  8.316157e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.591952e-13  4.247354e-13 -3.050180e-13  8.693344e-14 -1.179712e-12
# ...

# %%
card_data.shape
# Out:
# (284807, 31)

# %%
card_data.agg(["count","size","nunique"])
# Out:
#          Target      V1      V2      V3      V4      V5      V6      V7  \
# count    284807  284807  284807  284807  284807  284807  284807  284807
# size     284807  284807  284807  284807  284807  284807  284807  284807
# nunique  124592  275653  275655  275657  275654  275657  275652  275651
#
#              V8      V9  ...     V21     V22     V23     V24     V25     V26  \
# count    284807  284807  ...  284807  284807  284807  284807  284807  284807
# size     284807  284807  ...  284807  284807  284807  284807  284807  284807
# nunique  275643  275656  ...  275617  275644  275611  275645  275640  275647
#
#             V27     V28  Amount   Class
# count    284807  284807  284807  284807
# size     284807  284807  284807  284807
# nunique  275597  275558   32767       2
#
# [3 rows x 31 columns]

# %%
#checking Target Variable
defaulters = card_data[card_data.Target==1]
nondefaulters = card_data[card_data.Target==0]

# %%
# %matplotlib inline
card_data.hist(column="Target",figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000222DEA33E08>]],
#       dtype=object)

# %%
import pandas
import os
os.chdir('C:\Datasets')
df = pandas.read_csv("creditcard.csv")
X= df["Target"]
y = df["Amount"]

# %%
X
# Out:
# 0              0.0
# 1              0.0
# 2              1.0
# 3              1.0
# 4              2.0
#             ...
# 284802    172786.0
# 284803    172787.0
# 284804    172788.0
# 284805    172788.0
# 284806    172792.0
# Name: Target, Length: 284807, dtype: float64
